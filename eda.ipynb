# %%
# import kagglehub

# # Download latest version

# path = kagglehub.dataset_download("mechatronixs/tmdb-movies-dataset-20212025")

# print("Path to dataset files:", path)

# !cp -r /home/ilya/.cache/kagglehub/datasets/mechatronixs/tmdb-movies-dataset-20212025/versions/1/* data

# %%
import pandas as pd

# %%
df = pd.read_parquet('data/tmdb_movies_2021_2025.parquet')
print(df.shape)
df.head(2).T
# Out:
# (232586, 11)
#                                                                    0  \
# tmdb_id                                                       776797
# title                                                    The Sadness
# original_title                                                    哭悲
# release_date                                              2021-01-22
# genres                                               Horror|Thriller
# vote_average                                                   6.824
# vote_count                                                      1055
# popularity                                                    6.6556
# original_language                                                 zh
# overview           A young couple is pushed to the limits of sani...
# poster_url         https://image.tmdb.org/t/p/w500/fIiATfeF4CInWC...
#
#                                                                    1
# ...

# %%
df[df.vote_count > 20].shape
# Out:
# (7870, 11)

# %%
df.isna().mean()
# Out:
# tmdb_id              0.000000
# title                0.000000
# original_title       0.000000
# release_date         0.000000
# genres               0.000000
# vote_average         0.000000
# vote_count           0.000000
# popularity           0.000000
# original_language    0.000000
# overview             0.000000
# poster_url           0.129393
# dtype: float64

# %%
df.tmdb_id.nunique()
# Out:
# 232586
